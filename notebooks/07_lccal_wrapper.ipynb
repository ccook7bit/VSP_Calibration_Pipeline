# %%
import math
import argparse
import glob
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import readsav
import scipy
from scipy import stats as st
from astropy.io import fits
from decimal import Decimal

import lccal as lc

# %%
fits = '/users/cdcook/VSP/datafiles/xtetrans_c/'

# %%
lc.lccal(
    'R1', 'calibrate', fits, 185.4975, 37.38022222, 
    5,  # requested_refstars
    5,  # radius
    0.06,  # max_mean_error
    10,  # chisq
    True,  # avmag
    True,  # m_lim
    0.9,  # decent_epochs
    True,  # teststar
    False,  # xerrorbars
    True,  # plots
    True,  # log
    None,  # nights
    False  # verbose
)
