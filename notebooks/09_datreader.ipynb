    51643.354, 51643.356, 51643.358, 51643.360, 51643.362, 51643.365, 51643.367, 51643.369, 51643.371,
    51643.373, 51643.376, 51643.378, 51643.400, 51643.405, 51643.408, 51643.410, 51643.412, 51643.414,
    51643.416, 51643.419, 51643.421, 51643.423, 51643.425, 51643.462, 51643.464, 51643.466, 51643.468,
    51643.470, 51643.473, 51643.475, 51643.477, 51643.479, 51643.481, 51643.484, 51643.486, 51643.488
]
print(JD[:125])

# %%
lphase = lphase[:125]
vprecip = vprecip[:125]
mean = mean[:125]
stddev = stddev[:125]
median = median[:125]
dmoon = dmoon[:125]
skymon = skymon[:125]
clouds = clouds[:125]
JD = JD[:125]
limmag = limmag[:125]


dict = {'JD':JD, 'Mean':mean, 'StdDev':stddev, 'Median':median, 'Lphase':lphase, 'DMoon':dmoon, 'SkyMon':skymon, 'Clouds':clouds, 'VPrecip':vprecip, 'LimMag':limmag}
extDF = pd.DataFrame(dict)
extDF

# %%
night = '0409'
field = 'xtetrans_1b'
file_path = f'/lustre/work/client/users/cdcook/VSPData/outputs/{field}_night{night}_summary.csv'
print(file_path)
dataDF = pd.read_csv(file_path)
dataDF['Night'] = night
dataDF

# %%
# Assuming you have extDF and dataDF already defined
# If not, redefine them based on your previous data

# Concatenate the two DataFrames
bigDF = pd.concat([extDF, dataDF], axis=1)

# Print the combined DataFrame
bigDF

# %%
y2 = 'LimMag'
plt.figure(figsize=(18, 10))
sns.scatterplot(data=bigDF, x='JulianDate', y=y2)
plt.xlabel('Julian Date', fontsize=20)
plt.ylabel(y2, fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.title(f'{y2} of each exposure -- {field} {night}', fontsize=20)
plt.savefig(f"{directory}xtetrans_1b_0409_{y2}_over_JD.png")
plt.show()

# %%
x2 = 'Counts'
y2 = 'Median'
plt.figure(figsize=(18, 10))
sns.scatterplot(data=bigDF, x=x2, y=y2)
plt.xlabel(x2, fontsize=20)
plt.ylabel(y2, fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.title(f'{y2} over {x2} -- {field} {night}', fontsize=20)
plt.savefig(f"{directory}xtetrans_1b_0409_{y2}_over_{x2}.png")
plt.show()

# %%
# Plotting
plt.figure(figsize=(14, 10))

# Slope vs counts
plt.subplot(2, 2, 1)
sns.scatterplot(x='LimMag', y='Counts', data=bigDF)
plt.title('Counts over LimMag')
plt.xlabel('LimMag')
plt.ylabel('Counts')

# ABoffset vs counts
plt.subplot(2, 2, 2)
sns.scatterplot(x='LimMag', y='Slope', data=bigDF)
plt.title('Slope over LimMag')
plt.xlabel('LimMag')
plt.ylabel('Slope')

# ABoffset vs Slope
plt.subplot(2, 2, 3)
sns.scatterplot(x='LimMag', y='Mean', data=bigDF)
plt.title('Mean over LimMag')
plt.xlabel('LimMag')
plt.ylabel('Mean')

# Counts vs Limiting Mag
plt.subplot(2, 2, 4)
sns.scatterplot(x='LimMag', y='StdDev', data=bigDF)
plt.title('StdDev over LimMag')
plt.xlabel('LimMag')
plt.ylabel('StdDev')

plt.tight_layout()
plt.savefig(f"{directory}{field}_{night}_DiagParPlot.png")
plt.show()

# %%
# Drop the specified columns
bigDF = bigDF.drop(columns=['JD', 'JulianDate', 'LimitingMag', 'Night', 'ABoffset', 'VPrecip', 'Median'])
bigDF

# %%
sns.pairplot(bigDF)
plt.savefig(f"{directory}{field}_{night}_FullParPlot.png")
plt.show()
